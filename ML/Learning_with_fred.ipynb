# %%
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Get to coding

# %% [markdown]
# ## Initial setup
# We start by defining our dimensions and batch sizes for inceptionV3, in order for it to work properly according to its documentation.

# %%
# Defining image dimensions and batch size
IMG_SIZE = (299, 299) # InceptionV3 expects inputs of at least 75x75, but 299x299 is standard for its pre-trained weights.
BATCH_SIZE = 128
VAL_SPLIT = 0.33
EPOCHS = 100

DATA_DIR_TRAIN = './grocery_dataset/train'
print("Training data is located at ", DATA_DIR_TRAIN)

DATA_DIR_VAL = './grocery_dataset/val'
print("Validation data is located at ", DATA_DIR_VAL)

DATA_DIR_TEST = './grocery_dataset/test'
print("Validation data is located at ", DATA_DIR_TEST)
# Out:
# Training data is located at  ./grocery_dataset/train
# Validation data is located at  ./grocery_dataset/val
# Validation data is located at  ./grocery_dataset/test

# %% [markdown]
# ## Splitting the data

# %% [markdown]
# ### Datasplit for training

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR_TRAIN,
    labels='inferred',
    label_mode='int',
    validation_split=VAL_SPLIT,
    subset='training',
    seed=1337,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)
# Out:
# Found 15001 files belonging to 15 classes.
# Using 10051 files for training.
# I0000 00:00:1774349721.195552  474290 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 47187 MB memory:  -> device: 0, name: Quadro RTX 8000, pci bus id: 0000:83:00.0, compute capability: 7.5
# I0000 00:00:1774349721.197981  474290 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 11542 MB memory:  -> device: 1, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:02:00.0, compute capability: 6.1
# I0000 00:00:1774349721.198505  474290 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 11542 MB memory:  -> device: 2, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:03:00.0, compute capability: 6.1

# %% [markdown]
# ### Datasplit for validation

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR_VAL,
    labels='inferred',
    label_mode='int',
    validation_split=VAL_SPLIT,
    subset='validation',
    seed=1337,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)
# Out:
# Found 3000 files belonging to 15 classes.
# Using 990 files for validation.

# %% [markdown]
# ### Class naming

# %%
class_names = train_ds.class_names
num_classes = len(class_names)
print(f"Total number of classes: {num_classes}")
print(f"Product categories: {class_names}")
# Out:
# Total number of classes: 15
# Product categories: ['Bean', 'Bitter_Gourd', 'Bottle_Gourd', 'Brinjal', 'Broccoli', 'Cabbage', 'Capsicum', 'Carrot', 'Cauliflower', 'Cucumber', 'Papaya', 'Potato', 'Pumpkin', 'Radish', 'Tomato']

# %% [markdown]
# ## Optimizing for performance
# Adding caching is a good idea, since we dont want the GPU or CPU to wait for data loading.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Generating true labels

# %%
y_true = []
for images, labels in val_ds:
    y_true.extend(labels.numpy())

y_true = np.array(y_true)
# Out:
# 2026-03-24 11:55:25.931866: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ## Setting up the model
# ### Loading the pretrained base of InceptionV3
# Using InceptionV3'd ImageNet pre-trained dataset, but excluding the classification layer.

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras import layers, models

# Instantiate the base model
base_model = InceptionV3(
    input_shape=IMG_SIZE + (3,), # Expected input shape
    include_top=False,           # Excluding the 1000-class classifier layer
    weights='imagenet'           # Use weights pre-trained on ImageNet
)

# %% [markdown]
# ### Freezing the base model
# We freeze the weights of the base of InceptionV3, preventing the random training on our dataset from destroying the base knowledge and patterns learned from ImageNet.

# %%
base_model.trainable = False # FREEZE the layers

# %% [markdown]
# ### Adding our own little network
# We add our own little network (a new head) on top of the frozen base. This head is responsible for taking the features extracted by InceptionV3  and classifying them into our product categories (num_classes).

# %%
global_average_layer = layers.GlobalAveragePooling2D() # Reducing the 3D feature map to a 1D vector
prediction_layer = layers.Dense(num_classes, activation='softmax') # Our final classification layer

data_augmentation = models.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),   # Flips images randomly
  layers.RandomRotation(0.2),                     # Rotates up to 20% (72 degrees)
  layers.RandomZoom(0.2),                         # Zooms in/out by 20%
])

# Combine the base and the head using the Functional API
model = models.Sequential([
    # Add the augmentation
    data_augmentation,

    # Add a preprocessing layer for InceptionV3's required input scaling (if not handled by the data loader)
    layers.Lambda(tf.keras.applications.inception_v3.preprocess_input, input_shape=(299, 299, 3)),
    base_model,
    global_average_layer,
    layers.Dropout(0.2), # Good practice to prevent overfitting
    prediction_layer
])

model.build(input_shape=(None, 299, 299, 3))

# Print the summary to see your new, smaller model head
model.summary()

model.save("incep_model.keras")
model.save('saved_model_dir', save_format='tf')
# Out:
# /home/bram/.local/lib/python3.11/site-packages/keras/src/layers/core/lambda_layer.py:65: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_2 (Sequential)       │ (None, 299, 299, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda_1 (Lambda)               │ (None, 299, 299, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 8, 8, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 15)             │        30,735 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,833,519 (83.29 MB)
#  Trainable params: 30,735 (120.06 KB)
#  Non-trainable params: 21,802,784 (83.17 MB)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 29
#      26 model.summary()
#      28 model.save("incep_model.keras")
# ---> 29 model.save('saved_model_dir', save_format='tf')
#
# File ~/.local/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/.local/lib/python3.11/site-packages/keras/src/saving/saving_api.py:69, in save_model(model, filepath, overwrite, zipped, **kwargs)
#      62         logging.warning(
#      63             "The `save_format` argument is deprecated in Keras 3. "
#      64             "We recommend removing this argument as it can be inferred "
#      65             "from the file path. "
#      66             f"Received: save_format={save_format}"
#      67         )
#      68     else:
# ---> 69         raise ValueError(
#      70             "The `save_format` argument is deprecated in Keras 3. "
#      71             "Please remove this argument and pass a file path with "
#      72             "either `.keras` or `.h5` extension."
#      73             f"Received: save_format={save_format}"
#      74         )
#      75 if kwargs:
#      76     raise ValueError(
#      77         "The following argument(s) are not supported: "
#      78         f"{list(kwargs.keys())}"
#      79     )
#
# ValueError: The `save_format` argument is deprecated in Keras 3. Please remove this argument and pass a file path with either `.keras` or `.h5` extension.Received: save_format=tf

# %% [markdown]
# Compiling with adam optimizer to up the performance a little. Adam combines the best features of two optimizers i.e Momentum and RMSprop.

# %%
from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss=keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])

# %% [markdown]
# ## Time to train!
# Training without fine tuning first...

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=val_ds,
)
# Out:
# Epoch 1/100
# 2026-03-24 11:56:07.646342: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:15: Filling up shuffle buffer (this may take a while): 50 of 1000
# 2026-03-24 11:56:08.357031: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:482] Shuffle buffer filled.
# I0000 00:00:1774349773.936772  474525 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 95s 657ms/step - accuracy: 0.3363 - loss: 2.2705 - val_accuracy: 0.7636 - val_loss: 1.7064
# Epoch 2/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 27s 338ms/step - accuracy: 0.7498 - loss: 1.4538 - val_accuracy: 0.9141 - val_loss: 1.0652
# Epoch 3/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 228ms/step - accuracy: 0.8580 - loss: 0.9819 - val_accuracy: 0.9374 - val_loss: 0.7286
# Epoch 4/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 249ms/step - accuracy: 0.8965 - loss: 0.7306 - val_accuracy: 0.9515 - val_loss: 0.5438
# Epoch 5/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 230ms/step - accuracy: 0.9124 - loss: 0.5831 - val_accuracy: 0.9586 - val_loss: 0.4346
# Epoch 6/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 252ms/step - accuracy: 0.9257 - loss: 0.4820 - val_accuracy: 0.9616 - val_loss: 0.3604
# Epoch 7/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 232ms/step - accuracy: 0.9360 - loss: 0.4187 - val_accuracy: 0.9646 - val_loss: 0.3104
# Epoch 8/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 251ms/step - accuracy: 0.9382 - loss: 0.3688 - val_accuracy: 0.9636 - val_loss: 0.2685
# Epoch 9/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - accuracy: 0.9484 - loss: 0.3256 - val_accuracy: 0.9697 - val_loss: 0.2389
# Epoch 10/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 249ms/step - accuracy: 0.9474 - loss: 0.2993 - val_accuracy: 0.9697 - val_loss: 0.2164
# Epoch 11/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 232ms/step - accuracy: 0.9500 - loss: 0.2771 - val_accuracy: 0.9737 - val_loss: 0.1955
# Epoch 12/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 253ms/step - accuracy: 0.9564 - loss: 0.2506 - val_accuracy: 0.9737 - val_loss: 0.1793
# Epoch 13/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 232ms/step - accuracy: 0.9582 - loss: 0.2315 - val_accuracy: 0.9747 - val_loss: 0.1672
# Epoch 14/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 254ms/step - accuracy: 0.9618 - loss: 0.2160 - val_accuracy: 0.9747 - val_loss: 0.1538
# Epoch 15/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - accuracy: 0.9648 - loss: 0.2046 - val_accuracy: 0.9798 - val_loss: 0.1435
# Epoch 16/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 250ms/step - accuracy: 0.9677 - loss: 0.1867 - val_accuracy: 0.9758 - val_loss: 0.1359
# Epoch 17/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - accuracy: 0.9649 - loss: 0.1827 - val_accuracy: 0.9778 - val_loss: 0.1276
# Epoch 18/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 251ms/step - accuracy: 0.9670 - loss: 0.1751 - val_accuracy: 0.9788 - val_loss: 0.1215
# Epoch 19/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - accuracy: 0.9697 - loss: 0.1651 - val_accuracy: 0.9808 - val_loss: 0.1142
# Epoch 20/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 252ms/step - accuracy: 0.9712 - loss: 0.1530 - val_accuracy: 0.9798 - val_loss: 0.1086
# Epoch 21/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 232ms/step - accuracy: 0.9711 - loss: 0.1514 - val_accuracy: 0.9798 - val_loss: 0.1034
# Epoch 22/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 254ms/step - accuracy: 0.9739 - loss: 0.1431 - val_accuracy: 0.9818 - val_loss: 0.0985
# Epoch 23/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - accuracy: 0.9721 - loss: 0.1369 - val_accuracy: 0.9828 - val_loss: 0.0934
# Epoch 24/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 253ms/step - accuracy: 0.9742 - loss: 0.1314 - val_accuracy: 0.9788 - val_loss: 0.0914
# Epoch 25/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 18s 232ms/step - accuracy: 0.
 0.9959595799446106, 0.9959595799446106, 0.9959595799446106, 0.9959595799446106, 0.9979798197746277, 0.9969696998596191, 0.9969696998596191, 0.9969696998596191, 0.9959595799446106, 0.9979798197746277, 0.9959595799446106, 0.9959595799446106, 0.9959595799446106, 0.9979798197746277, 0.9989898800849915, 0.9989898800849915, 0.9989898800849915, 0.9989898800849915, 0.9979798197746277, 0.9989898800849915, 0.9979798197746277, 0.9979798197746277, 0.9989898800849915, 0.9979798197746277, 0.9989898800849915, 0.9979798197746277, 0.9989898800849915, 0.9989898800849915, 0.9979798197746277, 0.9989898800849915]

# %%
## Stress testing the model
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input

def TestAccuracy(path):
    img_path = path
    # Loading the image and resizing it to 299x299 (InceptionV3 standard)
    img = image.load_img(img_path, target_size=(299, 299))
    # Converting image to a numpy array and adding a "batch" dimension
    # (Keras expects a batch of images, even if it's just one)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    # Running the prediction
    predictions = model.predict(img_array)
    # Getting the class with the highest probability
    # score = tf.nn.softmax(predictions[0])
    score = predictions[0]
    predicted_class = class_names[np.argmax(score)]
    predicted_class_index = np.argmax(predictions[0])
    confidence = np.max(predictions[0]) * 100
    #for p in predictions:
    #    print(p / 100)
    
    print(f"I am {confidence:.2f}% sure this is a(n) {predicted_class} ({predicted_class_index}).")

TestAccuracy('./grocery_dataset/test/Tomato/1080.jpg')
TestAccuracy('./grocery_dataset/test/Cabbage/1080.jpg')
TestAccuracy('./grocery_dataset/test/Cucumber/1080.jpg')
TestAccuracy('./grocery_dataset/test/Carrot/1080.jpg')
TestAccuracy('./grocery_dataset/test/Radish/1080.jpg')
TestAccuracy('./grocery_dataset/test/Papaya/1200.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# I am 100.00% sure this is a(n) Tomato (14).
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# I am 99.97% sure this is a(n) Cabbage (5).
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# I am 99.92% sure this is a(n) Cucumber (9).
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# I am 99.98% sure this is a(n) Carrot (7).
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# I am 99.95% sure this is a(n) Radish (13).
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# I am 98.99% sure this is a(n) Papaya (10).

# %% [markdown]
# ### Setting up confusion matrix and heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def plot_grocery_confusion_matrix(y_true, y_pred, class_names):
    # 1. Compute the matrix
    cm = confusion_matrix(y_true, y_pred)
    
    # 2. Set up the figure size
    plt.figure(figsize=(10, 8))
    
    # 3. Create the heatmap
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, 
                yticklabels=class_names)
    
    plt.title('Grocery Recognition: Confusion Matrix')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.show()

# %% [markdown]
# ### Converting the model to TFJS

# %%
import tensorflow as tf
import tensorflowjs as tfjs

# 1. Load your newly trained Keras 3 model
model = tf.keras.models.load_model('./incep_model.keras')

# 2. Save it directly to the TensorFlow.js format
tfjs.converters.save_keras_model(model, './tfjs_model')

print("Conversion complete!")
# Out:
# WARNING:root:TensorFlow Decision Forests 1.12.0 is compatible with the following TensorFlow Versions: ['2.19.0']. However, TensorFlow 2.19.1 was detected. This can cause issues with the TF API and symbols in the custom C++ ops. See the TF and TF-DF compatibility table at https://github.com/tensorflow/decision-forests/blob/main/documentation/known_issues.md#compatibility-table.
# WARNING:root:Failure to load the inference.so custom c++ tensorflow ops. This error is likely caused the version of TensorFlow and TensorFlow Decision Forests are not compatible. Full error:/home/bram/.local/lib/python3.11/site-packages/tensorflow_decision_forests/tensorflow/ops/inference/inference.so: undefined symbol: _ZN10tensorflow20OpKernelConstruction21CtxFailureWithWarningEPKciRKN4absl12lts_202308026StatusE
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[20], line 2
#       1 import tensorflow as tf
# ----> 2 import tensorflowjs as tfjs
#       4 # 1. Load your newly trained Keras 3 model
#       5 model = tf.keras.models.load_model('./incep_model.keras')
#
# File ~/.local/lib/python3.11/site-packages/tensorflowjs/__init__.py:21
#      18 from __future__ import print_function
#      20 # pylint: disable=unused-imports
# ---> 21 from tensorflowjs import converters
#      22 from tensorflowjs import quantization
#      23 from tensorflowjs import version
#
# File ~/.local/lib/python3.11/site-packages/tensorflowjs/converters/__init__.py:21
#      18 from __future__ import print_function
#      20 # pylint: disable=unused-imports,line-too-long
# ---> 21 from tensorflowjs.converters.converter import convert
#      22 from tensorflowjs.converters.keras_h5_conversion import save_keras_model
#      23 from tensorflowjs.converters.keras_tfjs_loader import deserialize_keras_model
#
# File ~/.local/lib/python3.11/site-packages/tensorflowjs/converters/converter.py:38
#      36 from tensorflowjs.converters import keras_h5_conversion as conversion
#      37 from tensorflowjs.converters import keras_tfjs_loader
# ---> 38 from tensorflowjs.converters import tf_saved_model_conversion_v2
#      39 from zipfile import ZipFile, is_zipfile
#      42 def dispatch_keras_h5_to_tfjs_layers_model_conversion(
#      43     h5_path, output_dir=None, quantization_dtype_map=None,
#      44     split_weights_by_layer=False,
#      45     weight_shard_size_bytes=1024 * 1024 * 4,
#      46     metadata=None):
#
# File ~/.local/lib/python3.11/site-packages/tensorflowjs/converters/tf_saved_model_conversion_v2.py:28
#      25 from zipfile import ZipFile
#      27 # Required to load saved models that use TFDF.
# ---> 28 import tensorflow_decision_forests
#      29 import tensorflow as tf
#      30 from tensorflow.core.framework import function_pb2
#
# File ~/.local/lib/python3.11/site-packages/tensorflow_decision_forests/__init__.py:64
#      60 from tensorflow_decision_forests.tensorflow import check_version
#      62 check_version.check_version(__version__, compatible_tf_versions)
# ---> 64 from tensorflow_decision_forests import keras
#      65 from tensorflow_decision_forests.component import py_tree
#      66 from tensorflow_decision_forests.component.builder import builder
#
# File ~/.local/lib/python3.11/site-packages/tensorflow_decision_forests/keras/__init__.py:53
#      15 """Decision Forest in a Keras Model.
#      16
#      17 Usage example:
#    (...)     48 ```
#      49 """
#      51 from typing import Callable, List
# ---> 53 from tensorflow_decision_forests.keras import core
#      54 from tensorflow_decision_forests.keras import wrappers
#      56 # Utility classes
#
# File ~/.local/lib/python3.11/site-packages/tensorflow_decision_forests/keras/core.py:64
#      62 from tensorflow_decision_forests.component.inspector import inspector as inspector_lib
#      63 from tensorflow_decision_forests.component.tuner import tuner as tuner_lib
# ---> 64 from tensorflow_decision_forests.keras import core_inference
#      65 from tensorflow_decision_forests.tensorflow import cc_logging
#      66 from tensorflow_decision_forests.tensorflow import core as tf_core
#
# File ~/.local/lib/python3.11/site-packages/tensorflow_decision_forests/keras/core_inference.py:38
#      36 from tensorflow_decision_forests.tensorflow import core_inference as tf_core
#      37 from tensorflow_decision_forests.tensorflow import tf_logging
# ---> 38 from tensorflow_decision_forests.tensorflow.ops.inference import api as tf_op
#      39 from yggdrasil_decision_forests.learner import abstract_learner_pb2
#      40 from yggdrasil_decision_forests.learner.multitasker import multitasker_pb2
#
# File ~/.local/lib/python3.11/site-packages/tensorflow_decision_forests/tensorflow/ops/inference/api.py:183
#     181 from tensorflow_decision_forests.component.py_tree import dataspec as dataspec_lib
#     182 from tensorflow_decision_forests.tensorflow import tf1_compatibility
# --> 183 from tensorflow_decision_forests.tensorflow.ops.inference import op
#     184 from yggdrasil_decision_forests.dataset import data_spec_pb2
#     185 from yggdrasil_decision_forests.model import abstract_model_pb2
#
# File ~/.local/lib/python3.11/site-packages/tensorflow_decision_forests/tensorflow/ops/inference/op.py:15
#       1 # Copyright 2021 Google LLC.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from tensorflow_decision_forests.tensorflow.ops.inference.op_dynamic import *
#
# File ~/.local/lib/python3.11/site-packages/tensorflow_decision_forests/tensorflow/ops/inference/op_dynamic.py:24
#      22 except Exception as e:
#      23   check_version.info_fail_to_load_custom_op(e, "inference.so")
# ---> 24   raise e
#      26 # Importing all the symbols.
#      27 module = sys.modules[__name__]
#
# File ~/.local/lib/python3.11/site-packages/tensorflow_decision_forests/tensorflow/ops/inference/op_dynamic.py:21
#      18 import sys
#      20 try:
# ---> 21   ops = tf.load_op_library(resource_loader.get_path_to_datafile("inference.so"))
#      22 except Exception as e:
#      23   check_version.info_fail_to_load_custom_op(e, "inference.so")
#
# File ~/.conda-2024.02/envs/tf_gpu/lib/python3.11/site-packages/tensorflow/python/framework/load_library.py:54, in load_op_library(library_filename)
#      31 @tf_export('load_op_library')
#      32 def load_op_library(library_filename):
#      33   """Loads a TensorFlow plugin, containing custom ops and kernels.
#      34
#      35   Pass "library_filename" to a platform-specific mechanism for dynamically
#    (...)     52     RuntimeError: when unable to load the library or get the python wrappers.
#      53   """
# ---> 54   lib_handle = py_tf.TF_LoadLibrary(library_filename)
#      55   try:
#      56     wrappers = _pywrap_python_op_gen.GetPythonWrappers(
#      57         py_tf.TF_GetOpList(lib_handle))
#
# NotFoundError: /home/bram/.local/lib/python3.11/site-packages/tensorflow_decision_forests/tensorflow/ops/inference/inference.so: undefined symbol: _ZN10tensorflow20OpKernelConstruction21CtxFailureWithWarningEPKciRKN4absl12lts_202308026StatusE
