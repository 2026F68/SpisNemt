# %%
# Setup

# %%
EPOCHS = 150
BATCH_SIZE = 32
VAL_SPLIT = 0.33

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Manifest

# %%
job_types = [0, 1, 2]     # Full-time, Part-time, Contract
settings = [0, 1, 2]      # Remote, Hybrid, On-site
exp_levels = [0, 1, 2]    # Junior, Mid, Senior

mapping = {
    "job_types": ["full-time", "part-time", "contract"],
    "settings": ["remote", "hybrid", "on-site"],
    "exp_levels": ["junior", "mid", "senior"]
}

# %%
# Training

# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np

X_train = np.random.randint(0,3,size=(5000,6))

# 1. Extract the Job and User columns for comparison
job_types = X_train[:, 0]
job_settings = X_train[:, 1]
job_exps = X_train[:, 2]

user_types = X_train[:, 3]
user_settings = X_train[:, 4]
user_exps = X_train[:, 5]

# 2. Calculate matches (True/False arrays) multiplied by your weights
type_scores = (job_types == user_types).astype(int) * 50
setting_scores = (job_settings == user_settings).astype(int) * 30
exp_scores = (job_exps == user_exps).astype(int) * 20

# 3. Sum them up to get total scores for each of the 5000 rows
total_scores = type_scores + setting_scores + exp_scores

# 4. Apply the threshold to create the binary labels (0 or 1)
y_train = (total_scores >= 60).astype(int)

# %%
# The brain

# %%
from tensorflow.keras.callbacks import EarlyStopping

model = tf.keras.Sequential([
    layers.Dense(12, activation='relu', input_shape=(6,)), # Hidden Layer
    layers.Dense(1, activation='sigmoid')                 # Output Layer
])

# Add the Hidden Layer (12 neurons, 6 inputs, ReLU). 2 neurons per input is standard.
model.add(Dense(12, input_shape=(6,), activation='relu'))

# Add the Output Layer (1 neuron, Sigmoid). We simply need "0" for disliked, "1" for liked. 1 neuron for output is enough.
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=3)

model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_split=VAL_SPLIT, callbacks=[early_stopping])
# Out:
# 2026-02-19 15:01:38.511719: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 47187 MB memory:  -> device: 0, name: Quadro RTX 8000, pci bus id: 0000:83:00.0, compute capability: 7.5
# 2026-02-19 15:01:38.512305: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 11542 MB memory:  -> device: 1, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:02:00.0, compute capability: 6.1
# 2026-02-19 15:01:38.512856: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 11542 MB memory:  -> device: 2, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:03:00.0, compute capability: 6.1
# Epoch 1/150
# 2026-02-19 15:01:40.339901: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f844cc43250 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-02-19 15:01:40.339952: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 8000, Compute Capability 7.5
# 2026-02-19 15:01:40.339963: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA TITAN X (Pascal), Compute Capability 6.1
# 2026-02-19 15:01:40.339972: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (2): NVIDIA TITAN X (Pascal), Compute Capability 6.1
# 2026-02-19 15:01:40.350332: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-02-19 15:01:40.380326: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8800
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771509700.477406 2442537 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 210/210 [==============================] - 3s 7ms/step - loss: 0.6370 - accuracy: 0.7363 - val_loss: 0.5484 - val_accuracy: 0.8195
# Epoch 2/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4969 - accuracy: 0.8152 - val_loss: 0.4728 - val_accuracy: 0.8195
# Epoch 3/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4764 - accuracy: 0.8152 - val_loss: 0.4698 - val_accuracy: 0.8195
# Epoch 4/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.4718 - accuracy: 0.8152 - val_loss: 0.4641 - val_accuracy: 0.8195
# Epoch 5/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.4626 - accuracy: 0.8152 - val_loss: 0.4561 - val_accuracy: 0.8195
# Epoch 6/150
# 210/210 [==============================] - 2s 8ms/step - loss: 0.4550 - accuracy: 0.8152 - val_loss: 0.4503 - val_accuracy: 0.8195
# Epoch 7/150
# 210/210 [==============================] - 2s 7ms/step - loss: 0.4497 - accuracy: 0.8152 - val_loss: 0.4464 - val_accuracy: 0.8195
# Epoch 8/150
# 210/210 [==============================] - 2s 8ms/step - loss: 0.4459 - accuracy: 0.8152 - val_loss: 0.4437 - val_accuracy: 0.8195
# Epoch 9/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4429 - accuracy: 0.8152 - val_loss: 0.4416 - val_accuracy: 0.8195
# Epoch 10/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4403 - accuracy: 0.8152 - val_loss: 0.4398 - val_accuracy: 0.8195
# Epoch 11/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4380 - accuracy: 0.8152 - val_loss: 0.4383 - val_accuracy: 0.8195
# Epoch 12/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4360 - accuracy: 0.8152 - val_loss: 0.4370 - val_accuracy: 0.8195
# Epoch 13/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.4341 - accuracy: 0.8152 - val_loss: 0.4357 - val_accuracy: 0.8195
# Epoch 14/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4323 - accuracy: 0.8152 - val_loss: 0.4347 - val_accuracy: 0.8195
# Epoch 15/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4304 - accuracy: 0.8152 - val_loss: 0.4337 - val_accuracy: 0.8195
# Epoch 16/150
# 210/210 [==============================] - 2s 7ms/step - loss: 0.4286 - accuracy: 0.8152 - val_loss: 0.4331 - val_accuracy: 0.8195
# Epoch 17/150
# 210/210 [==============================] - 1s 5ms/step - loss: 0.4271 - accuracy: 0.8152 - val_loss: 0.4320 - val_accuracy: 0.8195
# Epoch 18/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.4255 - accuracy: 0.8158 - val_loss: 0.4312 - val_accuracy: 0.8201
# Epoch 19/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.4242 - accuracy: 0.8343 - val_loss: 0.4306 - val_accuracy: 0.8237
# Epoch 20/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4230 - accuracy: 0.8429 - val_loss: 0.4302 - val_accuracy: 0.8371
# Epoch 21/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4222 - accuracy: 0.8498 - val_loss: 0.4296 - val_accuracy: 0.8353
# Epoch 22/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4212 - accuracy: 0.8501 - val_loss: 0.4292 - val_accuracy: 0.8371
# Epoch 23/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4205 - accuracy: 0.8519 - val_loss: 0.4287 - val_accuracy: 0.8371
# Epoch 24/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4198 - accuracy: 0.8510 - val_loss: 0.4285 - val_accuracy: 0.8371
# Epoch 25/150
# 210/210 [==============================] - 1s 5ms/step - loss: 0.4193 - accuracy: 0.8522 - val_loss: 0.4281 - val_accuracy: 0.8371
# Epoch 26/150
# 210/210 [==============================] - 1s 5ms/step - loss: 0.4186 - accuracy: 0.8525 - val_loss: 0.4279 - val_accuracy: 0.8371
# Epoch 27/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.4181 - accuracy: 0.8525 - val_loss: 0.4275 - val_accuracy: 0.8353
# Epoch 28/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.4175 - accuracy: 0.8528 - val_loss: 0.4275 - val_accuracy: 0.8353
# Epoch 29/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4171 - accuracy: 0.8540 - val_loss: 0.4271 - val_accuracy: 0.8340
# Epoch 30/150
# 210/210 [==============================] - 1s 5ms/step - loss: 0.4164 - accuracy: 0.8531 - val_loss: 0.4271 - val_accuracy: 0.8353
# Epoch 31/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.4161 - accuracy: 0.8531 - val_loss: 0.4267 - val_accuracy: 0.8371
# Epoch 32/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.4157 - accuracy: 0.8528 - val_loss: 0.4266 - val_accuracy: 0.8371
# Epoch 33/150
# 210/210 [==============================] - 1s 5ms/step - loss: 0.4153 - accuracy: 0.8528 - val_loss: 0.4265 - val_accuracy: 0.8371
# Epoch 34/150
# 210/210 [==============================] - 1s 5ms/step - loss: 0.4148 - accuracy: 0.8537 - val_loss: 0.4264 - val_accuracy: 0.8371
# Epoch 35/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4144 - accuracy: 0.8528 - val_loss: 0.4263 - val_accuracy: 0.8371
# Epoch 36/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.4141 - accuracy: 0.8534 - val_loss: 0.4265 - val_accuracy: 0.8359
# Epoch 37/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.4138 - accuracy: 0.8546 - val_loss: 0.4264 - val_accuracy: 0.8359
# Epoch 38/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4139 - accuracy: 0.8531 - val_loss: 0.4263 - val_accuracy: 0.8365

# %%
model.predict([[2,2,2,0,0,0]])
# Out:
# 1/1 [==============================] - 0s 150ms/step
# array([[0.13736589]], dtype=float32)

# %%
model.predict([[0,0,0,0,1,2]])
# Out:
# 1/1 [==============================] - 0s 45ms/step
# array([[0.1938253]], dtype=float32)

# %%
model.predict([[0,0,0,0,1,1]])
# Out:
# 1/1 [==============================] - 0s 42ms/step
# array([[0.24669503]], dtype=float32)

# %%
model.predict([[0,1,0,0,2,0]])
# Out:
# 1/1 [==============================] - 0s 52ms/step
# array([[0.6197265]], dtype=float32)

# %%
model.predict([[0,1,2,0,2,2]])
# Out:
# 1/1 [==============================] - 0s 42ms/step
# array([[0.6197265]], dtype=float32)

# %%
model.predict([[0,0,0,0,0,0]])
# Out:
# 1/1 [==============================] - 0s 43ms/step
# array([[0.6197265]], dtype=float32)
