# %%
# Setup

# %%
EPOCHS = 150
BATCH_SIZE = 32
VAL_SPLIT = 0.33

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Manifest

# %%
job_types = [0, 1, 2]     # Full-time, Part-time, Contract
settings = [0, 1, 2]      # Remote, Hybrid, On-site
exp_levels = [0, 1, 2]    # Junior, Mid, Senior

mapping = {
    "job_types": ["full-time", "part-time", "contract"],
    "settings": ["remote", "hybrid", "on-site"],
    "exp_levels": ["junior", "mid", "senior"]
}

# %%
# Training

# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np

X_train = np.random.randint(0,3,size=(5000,6))

# 1. Extract the Job and User columns for comparison
job_types = X_train[:, 0]
job_settings = X_train[:, 1]
job_exps = X_train[:, 2]

user_types = X_train[:, 3]
user_settings = X_train[:, 4]
user_exps = X_train[:, 5]

# 2. Calculate matches (True/False arrays) multiplied by your weights
type_scores = (job_types == user_types).astype(int) * 50
setting_scores = (job_settings == user_settings).astype(int) * 30
exp_scores = (job_exps == user_exps).astype(int) * 20

# 3. Sum them up to get total scores for each of the 5000 rows
total_scores = type_scores + setting_scores + exp_scores

# 4. Apply the threshold to create the binary labels (0 or 1)
y_train = (total_scores >= 60).astype(int)

# %%
# The brain

# %%
from tensorflow.keras.callbacks import EarlyStopping

model = tf.keras.Sequential([
    layers.Dense(12, activation='relu', input_shape=(6,)), # Hidden Layer
    layers.Dense(1, activation='sigmoid')                 # Output Layer
])

# Add the Hidden Layer (12 neurons, 6 inputs, ReLU). 2 neurons per input is standard.
model.add(Dense(12, input_shape=(6,), activation='relu'))

# Add the Output Layer (1 neuron, Sigmoid). We simply need "0" for disliked, "1" for liked. 1 neuron for output is enough.
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()

model.save("mlp_model.keras")

early_stopping = EarlyStopping(monitor='val_loss', patience=3)

model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=VAL_SPLIT,
    callbacks=[early_stopping]
)
# Out:
# /home/bram/.local/lib/python3.11/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1774352120.402776  493503 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 30467 MB memory:  -> device: 0, name: Quadro RTX 8000, pci bus id: 0000:83:00.0, compute capability: 7.5
# I0000 00:00:1774352120.403484  493503 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 11374 MB memory:  -> device: 1, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:02:00.0, compute capability: 6.1
# I0000 00:00:1774352120.404028  493503 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 11374 MB memory:  -> device: 2, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:03:00.0, compute capability: 6.1
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 12)             │            84 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 12)             │            24 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            13 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 134 (536.00 B)
#  Trainable params: 134 (536.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# I0000 00:00:1774352122.491969  493677 service.cc:152] XLA service 0x7f71d8003e40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1774352122.491996  493677 service.cc:160]   StreamExecutor device (0): Quadro RTX 8000, Compute Capability 7.5
# I0000 00:00:1774352122.492006  493677 service.cc:160]   StreamExecutor device (1): NVIDIA TITAN X (Pascal), Compute Capability 6.1
# I0000 00:00:1774352122.492010  493677 service.cc:160]   StreamExecutor device (2): NVIDIA TITAN X (Pascal), Compute Capability 6.1
# 2026-03-24 12:35:22.580585: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1774352122.913045  493677 cuda_dnn.cc:529] Loaded cuDNN version 91002
#  52/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2053 - loss: 0.7601
# I0000 00:00:1774352123.719131  493677 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.5127 - loss: 0.6982 - val_accuracy: 0.8038 - val_loss: 0.6341
# Epoch 2/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8205 - loss: 0.5859 - val_accuracy: 0.8038 - val_loss: 0.5524
# Epoch 3/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8205 - loss: 0.5097 - val_accuracy: 0.8038 - val_loss: 0.5005
# Epoch 4/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8205 - loss: 0.4727 - val_accuracy: 0.8038 - val_loss: 0.4894
# Epoch 5/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8205 - loss: 0.4637 - val_accuracy: 0.8038 - val_loss: 0.4857
# Epoch 6/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8205 - loss: 0.4581 - val_accuracy: 0.8038 - val_loss: 0.4782
# Epoch 7/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8205 - loss: 0.
# Epoch 46/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9704 - loss: 0.0875 - val_accuracy: 0.9740 - val_loss: 0.0871
# Epoch 47/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9698 - loss: 0.0867 - val_accuracy: 0.9691 - val_loss: 0.0858
# Epoch 48/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9713 - loss: 0.0854 - val_accuracy: 0.9770 - val_loss: 0.0827
# Epoch 49/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9695 - loss: 0.0833 - val_accuracy: 0.9740 - val_loss: 0.0824
# Epoch 50/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9704 - loss: 0.0822 - val_accuracy: 0.9740 - val_loss: 0.0808
# Epoch 51/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9698 - loss: 0.0810 - val_accuracy: 0.9770 - val_loss: 0.0785
# Epoch 52/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9701 - loss: 0.0804 - val_accuracy: 0.9776 - val_loss: 0.0768
# Epoch 53/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9752 - loss: 0.0774 - val_accuracy: 0.9740 - val_loss: 0.0765
# Epoch 54/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9698 - loss: 0.0776 - val_accuracy: 0.9758 - val_loss: 0.0763
# Epoch 55/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9764 - loss: 0.0765 - val_accuracy: 0.9752 - val_loss: 0.0737
# Epoch 56/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9737 - loss: 0.0753 - val_accuracy: 0.9752 - val_loss: 0.0734
# Epoch 57/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9743 - loss: 0.0730 - val_accuracy: 0.9746 - val_loss: 0.0719
# Epoch 58/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9743 - loss: 0.0728 - val_accuracy: 0.9794 - val_loss: 0.0705
# Epoch 59/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9758 - loss: 0.0717 - val_accuracy: 0.9812 - val_loss: 0.0691
# Epoch 60/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9743 - loss: 0.0710 - val_accuracy: 0.9782 - val_loss: 0.0693
# Epoch 61/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9755 - loss: 0.0693 - val_accuracy: 0.9703 - val_loss: 0.0749
# Epoch 62/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9755 - loss: 0.0695 - val_accuracy: 0.9776 - val_loss: 0.0677
# Epoch 63/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9776 - loss: 0.0691 - val_accuracy: 0.9800 - val_loss: 0.0668
# Epoch 64/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9776 - loss: 0.0671 - val_accuracy: 0.9703 - val_loss: 0.0681
# Epoch 65/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9785 - loss: 0.0673 - val_accuracy: 0.9758 - val_loss: 0.0655
# Epoch 66/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9782 - loss: 0.0675 - val_accuracy: 0.9794 - val_loss: 0.0642
# Epoch 67/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9755 - loss: 0.0671 - val_accuracy: 0.9830 - val_loss: 0.0616
# Epoch 68/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9812 - loss: 0.0648 - val_accuracy: 0.9806 - val_loss: 0.0614
# Epoch 69/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9800 - loss: 0.0628 - val_accuracy: 0.9836 - val_loss: 0.0610
# Epoch 70/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9809 - loss: 0.0622 - val_accuracy: 0.9812 - val_loss: 0.0595
# Epoch 71/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9785 - loss: 0.0634 - val_accuracy: 0.9855 - val_loss: 0.0590
# Epoch 72/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9791 - loss: 0.0615 - val_accuracy: 0.9794 - val_loss: 0.0602
# Epoch 73/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9809 - loss: 0.0604 - val_accuracy: 0.9843 - val_loss: 0.0570
# Epoch 74/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9803 - loss: 0.0599 - val_accuracy: 0.9843 - val_loss: 0.0576
# Epoch 75/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9833 - loss: 0.0585 - val_accuracy: 0.9782 - val_loss: 0.0625
# Epoch 76/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9800 - loss: 0.0594 - val_accuracy: 0.9788 - val_loss: 0.0579

# %%
model.predict([[2,2,2,0,0,0]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model.predict([[2,2,2,0,0,0]])
#
# File ~/.local/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/.local/lib/python3.11/site-packages/keras/src/trainers/data_adapters/__init__.py:163, in get_data_adapter(x, y, sample_weight, batch_size, steps_per_epoch, shuffle, class_weight)
#     155     return GeneratorDataAdapter(x)
#     156     # TODO: should we warn or not?
#     157     # warnings.warn(
#     158     #     "`shuffle=True` was passed, but will be ignored since the "
#    (...)    161     # )
#     162 else:
# --> 163     raise ValueError(f"Unrecognized data type: x={x} (of type {type(x)})")
#
# ValueError: Unrecognized data type: x=[[2, 2, 2, 0, 0, 0]] (of type <class 'list'>)

# %%
model.predict([[0,0,0,0,1,2]])

# %%
model.predict([[0,0,0,0,1,1]])

# %%
model.predict([[0,1,0,0,2,0]])

# %%
model.predict([[0,1,2,0,2,2]])

# %%
model.predict([[0,0,0,0,0,0]])

# %%
tensorflowjs_converter \
    --input_format=tf_saved_model \
    --output_node_names='MobilenetV1/Predictions/Reshape_1' \
    --saved_model_tags=serve \
    /mobilenet/saved_model \
    /mobilenet/web_model
# Out:
#   Cell In[10], line 1
#     tensorflowjs_converter \
#     ^
# SyntaxError: cannot assign to expression
