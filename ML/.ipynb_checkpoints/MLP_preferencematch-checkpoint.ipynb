# %% [markdown]
# # Recipe Preference Matcher — MLP
#
# Trains a tiny on-device MLP that scores how well a TheMealDB recipe matches a user's saved cuisine area and category preferences.
#
# **Input (4 floats):**
# - `area_match` — 1.0 if recipe's strArea is in user's area prefs, else 0.0
# - `cat_match` — 1.0 if recipe's strCategory is in user's category prefs, else 0.0
# - `area_norm` — same as area_match (extensible in future to fraction of prefs matched)
# - `cat_norm` — same as cat_match
#
# **Output:** probability in [0, 1] — higher means better match
#
# **Label rule:** positive (1) if `area_match*60 + cat_match*40 >= 40` — i.e. any single feature match = positive

# %% [markdown]
# ## Cell 1 — Config

# %%
EPOCHS = 200
BATCH_SIZE = 64
VAL_SPLIT = 0.2
N_SAMPLES = 10_000

# %% [markdown]
# ## Cell 2 — Vocabulary Manifest
#
# These must match the values used in the React Native app (`account.tsx` preference options).
# The model itself does not depend on this list at inference time — it only needs the binary match signals.

# %%
# TheMealDB canonical strArea values
AREAS = [
    "American", "British", "Canadian", "Chinese", "Croatian",
    "Dutch", "Egyptian", "Filipino", "French", "Greek",
    "Indian", "Irish", "Italian", "Jamaican", "Japanese",
    "Kenyan", "Malaysian", "Mexican", "Moroccan", "Polish",
    "Portuguese", "Russian", "Spanish", "Thai", "Tunisian",
    "Turkish", "Ukrainian", "Unknown", "Vietnamese",
]

# TheMealDB canonical strCategory values
CATEGORIES = [
    "Beef", "Breakfast", "Chicken", "Dessert", "Goat",
    "Lamb", "Miscellaneous", "Pasta", "Pork", "Seafood",
    "Side", "Starter", "Vegan", "Vegetarian",
]

N_AREAS = len(AREAS)          # 29
N_CATEGORIES = len(CATEGORIES) # 14
print(f"Areas: {N_AREAS}, Categories: {N_CATEGORIES}")
# Out:
# Areas: 29, Categories: 14

# %% [markdown]
# ## Cell 3 — Training Data Generation
#
# Synthetic data: simulate random (recipe, user_prefs) pairs and label them based on match quality.

# %%
import numpy as np

rng = np.random.default_rng(42)

def generate_sample():
    # Simulate a recipe: one area, one category
    recipe_area_idx = rng.integers(0, N_AREAS)
    recipe_cat_idx  = rng.integers(0, N_CATEGORIES)

    # Simulate user preferences: 0–5 areas, 0–5 categories
    n_user_areas = rng.integers(0, 6)
    n_user_cats  = rng.integers(0, 6)
    user_areas   = set(rng.choice(N_AREAS, n_user_areas, replace=False).tolist())
    user_cats    = set(rng.choice(N_CATEGORIES, n_user_cats, replace=False).tolist())

    # Binary match signals
    area_match = 1.0 if recipe_area_idx in user_areas else 0.0
    cat_match  = 1.0 if recipe_cat_idx  in user_cats  else 0.0

    # 4-float input vector
    # Features 0,1: direct match signals
    # Features 2,3: same for now (extensible — could become fraction of prefs matched)
    x = np.array([area_match, cat_match, area_match, cat_match], dtype=np.float32)

    # Label: 1 if area_match*60 + cat_match*40 >= 40 (any single match = positive)
    score = area_match * 60 + cat_match * 40
    y = 1.0 if score >= 40 else 0.0

    return x, y


samples = [generate_sample() for _ in range(N_SAMPLES)]
X_train = np.stack([s[0] for s in samples])
y_train = np.array([s[1] for s in samples], dtype=np.float32)

print(f"X_train shape: {X_train.shape}")
print(f"Positive rate: {y_train.mean():.2f}")
# Out:
# X_train shape: (10000, 4)
# Positive rate: 0.25

# %% [markdown]
# ## Cell 4 — Class Balance Check

# %%
from collections import Counter

counts = Counter(y_train.astype(int))
print(f"Label distribution: {dict(counts)}")
ratio = counts[0] / max(counts[1], 1)
print(f"Negative:Positive ratio = {ratio:.1f}:1")
if ratio > 4:
    print("WARNING: class imbalance > 4:1 — consider adding class_weight to model.fit()")
# Out:
# Label distribution: {np.int64(1): 2487, np.int64(0): 7513}
# Negative:Positive ratio = 3.0:1

# %% [markdown]
# ## Cell 5 — Model Architecture
#
# Tiny MLP: 4 inputs → 8 hidden (ReLU) → 1 output (Sigmoid).
# Total parameters: (4×8 + 8) + (8×1 + 1) = **49 weights** → < 5 KB TFJS shard.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping

model = tf.keras.Sequential([
    layers.Dense(8, activation="relu", input_shape=(4,)),
    layers.Dense(1, activation="sigmoid"),
], name="preference_mlp")

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy", tf.keras.metrics.AUC(name="auc")],
)

model.summary()
# Out:
# /home/bram/.local/lib/python3.11/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "preference_mlp"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49 (196.00 B)
#  Trainable params: 49 (196.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Cell 6 — Training

# %%
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=2,
    restore_best_weights=True,
)

history = model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=VAL_SPLIT,
    callbacks=[early_stopping],
)

print(f"\nFinal val_accuracy: {max(history.history['val_accuracy']):.4f}")
print(f"Final val_auc:      {max(history.history['val_auc']):.4f}")
# Out:
# Epoch 1/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9940 - auc: 1.0000 - loss: 0.5606 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.5187
# Epoch 2/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.4861 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.4579
# Epoch 3/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.4321 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.4094
# Epoch 4/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.3883 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.3696
# Epoch 5/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.3515 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.3354
# Epoch 6/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.3196 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.3056
# Epoch 7/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2916 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.2792
# Epoch 8/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2668 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.2557
# Epoch 9/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2447 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.2348
# Epoch 10/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2248 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.2160
# Epoch 11/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2070 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1990
# Epoch 12/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1909 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1837
# Epoch 13/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1764 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1699
# Epoch 14/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1633 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1574
# Epoch 15/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1513 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1459
# Epoch 16/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1404 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1355
# Epoch 17/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1305 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1260
# Epoch 18/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1214 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1173
# Epoch 19/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1131 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1094
# Epoch 20/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1055 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1020
# Epoch 21/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0985 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0953
# Epoch 22/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0920 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0891
# Epoch 23/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0861 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0834
# Epoch 24/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0806 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0781
# Epoch 25/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0755 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0732
# Epoch 26/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0708 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0687
# Epoch 27/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0664 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0645
# Epoch 28/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0624 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0606
# Epoch 29/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0586 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0569
# Epoch 30/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0551 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0535
# Epoch 31/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0518 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0504
# Epoch 32/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0488 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0474
# Epoch 33/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0459 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0447
# Epoch 34/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0433 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0421
# Epoch 35/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0408 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0397
# Epoch 36/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0385 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0374
# Epoch 37/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0363 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0353
# Epoch 38/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0343 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0333
# Epoch 39/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0323 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0315
# Epoch 40/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0305 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0297
# Epoch 41/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0288 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0281
# Epoch 42/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0273 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0265
# Epoch 43/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0258 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0251
# Epoch 44/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0244 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0237
# Epoch 45/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0230 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0224
# Epoch 46/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0218 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0212
# Epoch 47/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0206 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0201
# Epoch 48/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0195 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0190
# Epoch 49/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0185 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0180
# Epoch 50/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0175 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0170
# Epoch 51/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0165 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0161
# Epoch 52/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0157 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0153
# Epoch 53/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0148 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0145
# Epoch 54/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0140 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0137
# Epoch 55/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0133 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0130
# Epoch 56/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0126 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0123
# Epoch 57/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0119 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0116
# Epoch 58/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0113 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0110
# Epoch 59/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0107 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0105
# Epoch 60/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0102 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0099
# Epoch 61/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0096 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0094
# Epoch 62/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0091 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0089
# Epoch 63/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0087 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0085
# Epoch 64/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0082 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0080
# Epoch 65/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0078 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0076
# Epoch 66/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0074 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0072
# Epoch 67/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0070 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0068
# Epoch 68/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0066 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0065
# Epoch 69/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0063 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0062
# Epoch 70/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0058
# Epoch 71/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0055
# Epoch 72/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0054 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0052
# Epoch 73/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0050
# Epoch 74/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0048 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0047
# Epoch 75/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0045
# Epoch 76/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0043
# Epoch 77/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0040
# Epoch 78/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0038
# Epoch 79/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0037 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0036
# Epoch 80/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0034
# Epoch 81/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0033
# Epoch 82/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0031
# Epoch 83/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0029
# Epoch 84/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0028
# Epoch 85/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0027
# Epoch 86/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0025
# Epoch 87/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0024
# Epoch 88/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0023
# Epoch 89/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0022
# Epoch 90/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0020
# Epoch 91/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0019
# Epoch 92/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0018
# Epoch 93/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0017
# Epoch 94/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0017
# Epoch 95/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0016
# Epoch 96/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0015
# Epoch 97/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0014
# Epoch 98/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0013
# Epoch 99/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0013
# Epoch 100/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0012
# Epoch 101/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0012
# Epoch 102/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0011
# Epoch 103/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0010
# Epoch 104/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 9.8724e-04
# Epoch 105/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 9.6031e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 9.3725e-04
# Epoch 106/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 9.1169e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 8.8977e-04
# Epoch 107/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 8.6554e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 8.4472e-04
# Epoch 108/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 8.2171e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 8.0205e-04
# Epoch 109/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 7.8013e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 7.6141e-04
# Epoch 110/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 7.4064e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 7.2281e-04
# Epoch 111/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 7.0316e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 6.8625e-04
# Epoch 112/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 6.6758e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 6.5159e-04
# Epoch 113/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 6.3382e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 6.1854e-04
# Epoch 114/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 6.0174e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 5.8732e-04
# Epoch 115/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 5.7131e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 5.5762e-04
# Epoch 116/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 5.4241e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 5.2942e-04
# Epoch 117/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 5.1498e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 5.0264e-04
# Epoch 118/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.8894e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 4.7718e-04
# Epoch 119/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.6421e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 4.5312e-04
# Epoch 120/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.4074e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 4.3013e-04
# Epoch 121/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.1845e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 4.0846e-04
# Epoch 122/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.9730e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 3.8779e-04
# Epoch 123/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.7721e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 3.6815e-04
# Epoch 124/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.5814e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 3.4956e-04
# Epoch 125/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.4003e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 3.3190e-04
# Epoch 126/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.2285e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 3.1511e-04
# Epoch 127/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.0653e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 2.9916e-04
# Epoch 128/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.9103e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 2.8407e-04
# Epoch 129/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.7633e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 2.6969e-04
# Epoch 130/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.6236e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 2.5608e-04
# Epoch 131/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.4910e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 2.4312e-04
# Epoch 132/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.3652e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 2.3084e-04
# Epoch 133/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.2457e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 2.1919e-04
# Epoch 134/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.1322e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 2.0810e-04
# Epoch 135/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.0245e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.9761e-04
# Epoch 136/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.9222e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.8764e-04
# Epoch 137/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.8251e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.7814e-04
# Epoch 138/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.7329e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.6913e-04
# Epoch 139/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.6453e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.6058e-04
# Epoch 140/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.5622e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.5249e-04
# Epoch 141/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.4833e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.4478e-04
# Epoch 142/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.4084e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.3747e-04
# Epoch 143/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.3372e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.3052e-04
# Epoch 144/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.2697e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.2392e-04
# Epoch 145/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.2055e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.1766e-04
# Epoch 146/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.1446e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.1173e-04
# Epoch 147/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.0868e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.0609e-04
# Epoch 148/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.0320e-04 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.0073e-04
# Epoch 149/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 9.7985e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 9.5643e-05
# Epoch 150/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 9.3037e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 9.0817e-05
# Epoch 151/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 8.8339e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 8.6227e-05
# Epoch 152/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 8.3877e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 8.1868e-05
# Epoch 153/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 7.9640e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 7.7737e-05
# Epoch 154/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 7.5618e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 7.3805e-05
# Epoch 155/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 7.1800e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 7.0077e-05
# Epoch 156/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 6.8174e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 6.6543e-05
# Epoch 157/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 6.4733e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 6.3182e-05
# Epoch 158/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 6.1465e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 5.9997e-05
# Epoch 159/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 5.8362e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 5.6968e-05
# Epoch 160/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 5.5416e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 5.4082e-05
# Epoch 161/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 5.2618e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 5.1355e-05
# Epoch 162/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.9961e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 4.8766e-05
# Epoch 163/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.7439e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 4.6309e-05
# Epoch 164/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.5045e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 4.3966e-05
# Epoch 165/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.2771e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 4.1749e-05
# Epoch 166/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.0612e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 3.9638e-05
# Epoch 167/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.8562e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 3.7639e-05
# Epoch 168/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.6616e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 3.5738e-05
# Epoch 169/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.4768e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 3.3937e-05
# Epoch 170/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.3015e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 3.2222e-05
# Epoch 171/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.1348e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 3.0600e-05
# Epoch 172/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.9767e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 2.9055e-05
# Epoch 173/200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.8265e-05 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 2.7591e-05
# Epoch 174/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 7
#       1 early_stopping = EarlyStopping(
#       2     monitor="val_loss",
#       3     patience=10,
#       4     restore_best_weights=True,
#       5 )
# ----> 7 history = model.fit(
#       8     X_train,
#       9     y_train,
#      10     epochs=EPOCHS,
#      11     batch_size=BATCH_SIZE,
#      12     validation_split=VAL_SPLIT,
#      13     callbacks=[early_stopping],
#      14 )
#      16 print(f"\nFinal val_accuracy: {max(history.history['val_accuracy']):.4f}")
#      17 print(f"Final val_auc:      {max(history.history['val_auc']):.4f}")
#
# File ~/.local/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File ~/.local/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File ~/.conda-2024.02/envs/tf_gpu/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda-2024.02/envs/tf_gpu/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/.conda-2024.02/envs/tf_gpu/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/.conda-2024.02/envs/tf_gpu/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/.conda-2024.02/envs/tf_gpu/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/.conda-2024.02/envs/tf_gpu/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/.conda-2024.02/envs/tf_gpu/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/.conda-2024.02/envs/tf_gpu/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File ~/.conda-2024.02/envs/tf_gpu/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Cell 7 — Smoke Tests
#
# Verify the model learned the correct direction. Expected:
# - Both match → high score (> 0.9)
# - Area-only match → medium-high (> 0.7)
# - Category-only match → medium (> 0.6)
# - No match → low (< 0.2)

# %%
test_cases = [
    ([1.0, 1.0, 1.0, 1.0], "both match    → expect HIGH  (> 0.9)"),
    ([1.0, 0.0, 1.0, 0.0], "area only     → expect MED-H (> 0.7)"),
    ([0.0, 1.0, 0.0, 1.0], "category only → expect MED   (> 0.6)"),
    ([0.0, 0.0, 0.0, 0.0], "no match      → expect LOW   (< 0.2)"),
]

for x_vals, label in test_cases:
    x = np.array([x_vals], dtype=np.float32)
    score = float(model.predict(x, verbose=0)[0][0])
    print(f"{label}  →  score = {score:.3f}")

# %% [markdown]
# ## Cell 8 — Save Keras Model

# %%
model.save("preference_mlp.keras")
print("Saved: preference_mlp.keras")

# %% [markdown]
# ## Cell 9 — Convert to TFJS
#
# Run this cell to produce `./tfjs_preference_mlp/model.json` and a single small `.bin` weight shard.
# Then copy the directory contents into `SpisNemt_FE/src/ml/MLP/`.
#
# **Prerequisite:** `pip install tensorflowjs`

# %%
# %%bash
# tensorflowjs_converter \
#     --input_format=keras \
#     --output_format=tfjs_graph_model \
#     preference_mlp.keras \
#     ./tfjs_preference_mlp
#
# echo "\nGenerated files:"
# ls -lh ./tfjs_preference_mlp/

# %% [markdown]
# ## Cell 10 — Next Steps
#
# After the converter runs:
#
# 1. Copy `./tfjs_preference_mlp/model.json` and `./tfjs_preference_mlp/group1-shard1of1.bin` into `SpisNemt_FE/src/ml/MLP/`
# 2. The TypeScript service at `SpisNemt_FE/src/services/ml/preferencesMatcher.ts` will load them via `bundleResourceIO`
# 3. No code changes needed — asset paths are already wired up
